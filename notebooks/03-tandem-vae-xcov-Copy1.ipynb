# %% [markdown]
# # Spatial and Identity Tandem VAE
# Inspired by Olshausen and Cheung's work we try to segregate identity from spatial information in an unsupervised way

# %% [markdown]
# TODO:
# - ~~Implement cross-covariance penalty~~
#     - https://stackoverflow.com/questions/45874928/how-to-compute-covariance-in-tensorflow
#     - https://arxiv.org/abs/1412.6583
#     - https://en.wikipedia.org/wiki/Cross-covariance
#     - ~~Needs to be per-batch basis, use regularization?~~ Just operate on the layer, it has shape [batch,dim]

# %%
import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import keras as keras
from keras.layers import Dense,Input,Lambda,Concatenate,Activation, Conv2D
from keras.models import Model,load_model
from keras.utils import to_categorical
from keras.callbacks import LambdaCallback
from keras.losses import categorical_crossentropy,logcosh
import keras.backend as K
from keras.datasets import mnist
from keras.metrics import categorical_accuracy
from keras.callbacks import BaseLogger,RemoteMonitor,TerminateOnNaN

from tqdm import tqdm as tqdm

from src.models import build_dense
from src.utils import ElasticSearchMonitor
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load train and test MNIST data from Keras

# %%
# (x_train, y_train,w_train), (x_test,y_test,w_test) = emnist.load_byclass()
(x_train, y_train), (x_test,y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
class_ids = np.unique(y_train)
masks_train = [y_train==i for i in class_ids]
masks_test = [y_test==i for i in class_ids]

y_test_oh = to_categorical(y_test,num_classes=10)
y_train_oh = to_categorical(y_train,num_classes=10)

digit_mask = lambda y: y<10 
uppercase = lambda y: (y>=10) & (y<36)
lowercase = lambda y: (y>=36) & (y<62)

input_shape=(784,)
print(x_train.shape)
print(x_test.shape)
# plt.imshow(x_train[masks[4]][10].reshape(28,28).T)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# Make dataset thats just a copy with random offsets
num_train = len(y_train)
num_test = len(y_test)

# pre-allocate shifted inputs
sx_train = np.empty((num_train,784*4))
sx_test = np.empty((num_test,784*4))

# pre-allocate list of dx,dy shifts for each image
delta_train = np.empty((num_train,2))
delta_test = np.empty((num_test,2))

def random_offset(X,scale=2):
    bg_size=(28*scale,28*scale)
    
    dx = int(np.random.randint(-10,10))+14
    dy = int(np.random.randint(-10,10))+14
    
    dx = max(dx,0)
    dx = min(dx,bg_size[0]-28)
    
    dy = max(dy,0)
    dy = min(dy,bg_size[0]-28)
#     print(dx,dy)
    new_im = np.zeros(bg_size)
    new_im[dx:dx+28,dy:dy+28] = letter
    
    return new_im,np.array([dx,dy])

print('making training data...')
for i in tqdm(np.arange(num_train)):
    letter = x_train[i].reshape(28,28)
    new_im,offsets = random_offset(letter,scale=2)
    sx_train[i] = new_im.reshape(1,4*784)
    delta_train[i] = offsets

print('making testing data...')
for i in tqdm(np.arange(num_test)):
    letter = x_test[i].reshape(28,28)
    new_im,offsets = random_offset(letter,scale=2)
    sx_test[i] = new_im.reshape(1,4*784)
    delta_test[i] = offsets
# Out:
#   6%|▋         | 3797/60000 [00:00<00:01, 37954.74it/s]
# making training data...
# 100%|██████████| 60000/60000 [00:01<00:00, 39048.47it/s]
#  36%|███▌      | 3624/10000 [00:00<00:00, 36229.15it/s]
# making testing data...
# 100%|██████████| 10000/10000 [00:00<00:00, 35971.79it/s]

# %%
plt.hist2d(delta_test[:,0],delta_test[:,1],bins=20);

# %% [markdown]
# Example of a shifted digit on a larger background

# %%
i = 250
print(y_train[masks_train[3]][i])
fig,axs = plt.subplots(1,2,figsize=(10,5))
axs[0].imshow(x_train[masks_train[3]][i].reshape(28,28))
axs[1].imshow(sx_train[masks_train[3]][i].reshape(28*2,28*2))

axs[0].get_xaxis().set_visible(False)
axs[0].get_yaxis().set_visible(False)
axs[1].get_xaxis().set_visible(False)
axs[1].get_yaxis().set_visible(False)

fig.savefig('./shifted_mnist_3.png',dpi=300)
# Out:
# 3

# %% [markdown]
# ## Define Model
# ```
# |     Inputs (3136)     |
#  \      h1 (1500)      /
#   |     h2 (1500)     |
#
#      |z_hat| |y_hat|
#
#     /   h3 (1500)   \
#    |    h4 (1500)    |
# ```

# %%
encoding_dims = [3000,1500]
z_dim = 2
y_dim = 5

# randomly shifted image
inputs = Input(shape=(784*4,))
# encoded = Dense(encoding_dim,activation='relu')(inputs)
encoded = build_dense(inputs,encoding_dims,activations='relu')

# %% [markdown]
# > dist_sample = sampler( args=(mean,std) )
# >
# >parameterizes a normal distribution from a mean and std and samples it

# %%
def sampler(args):
    mean,log_stddev = args
    std_norm = K.random_normal(shape=(K.shape(mean)[0],K.shape(mean)[1]),mean=0,stddev=1)
    
    return mean + K.exp(log_stddev) * std_norm

# %%
z_mean = Dense(z_dim,name='z_mean')(encoded)
lat_vec = z_mean
# z_log_sigma = Dense(z_dim)(encoded)
# "layerize" z_hat random variable
# lat_vec = Lambda(sampler,name='z_sample')([z_mean,z_log_sigma])

y_hat = Dense(10,activation='softmax',name='y_hat')(encoded)
# y_hat = Dense(y_dim,name='y_mean')(encoded)
# y_hat_sigma = Dense(y_dim,name='y_sigma')(encoded)
# y_hat = Lambda(sampler, name='y_hat')([y_hat_mean,y_hat_sigma])
# y_hat = Dense(2,name='y_hat')(encoded)

# latent class repr
# y_hat = Dense(2,activation='sigmoid')(encoded)
# y_int = Dense(50,activation='relu')(y_hat)
# y_int = Dense(250,activation='relu')(y_int)
y_class = y_hat

# Concatenate with One-hot identity vector
combo_vec = Concatenate()([lat_vec,y_hat])

# Expand back out input dimensions (batch_size x im_size)

decoded_mean = build_dense(combo_vec,[encoding_dims[1],encoding_dims[0]]+[4*784],activations=['relu','relu','sigmoid'])
# decoded_mean = build_dense(combo_vec,[encoding_dims[1],encoding_dims[0]]+[4*784],activations=['relu','relu','sigmoid'])
tandem_vae = Model(inputs,decoded_mean)

# %% [markdown]
# #### Combined Loss function
#
# - Reconstruction loss (sum of squared error)
#
# $ \sum\limits_{n} (X - \bar{X})^2 $
# - Cross-covariance (XCov) of latent vars (z_hat, y_hat)
# - Classification loss (categorical crossentropy)

# %%
from src.losses import *
        
def acc(y_true,y_pred):
    return categorical_accuracy(y_true,y_class)

def kl_loss_tot(y_true,y_pred):
    return kl_loss_z(y_true,y_pred)

def xentropy(y_true,y_pred):
    return 3*categorical_crossentropy(y_true,y_class)

def recon_mse(y_true,y_pred):
    return K.mean(K.sum(K.square(y_pred-inputs),axis=-1),axis=0)

# %%
recon_loss = ReconstructionLoss(inputs=inputs,outputs=decoded_mean)
xcov = XCov(y_hat,z_mean,weight=1)
# kl_loss_z = KLDivergenceLoss(z_log_sigma,z_mean,weight=0.001,name='DKL_z')
# kl_loss_y = KLDivergenceLoss(y_hat_sigma,y_hat_mean, weight=0.0001, name='DKL_y')

# %%
tandem_vae = Model(inputs,decoded_mean)
def vae_loss(y_true,y_pred):
    total_loss = 0
    loss_fns = [
        K.sum(recon_loss(y_true,y_pred)),
        10*xcov(y_true,y_pred),
        K.sum(10*categorical_crossentropy(y_true,y_class)),
#         K.sum(kl_loss_z(y_true,y_pred))/128,
#         K.sum(kl_loss_y(y_true,y_pred))
    ]
#     print(K.int_shape(xcov(y_true,y_pred)))
    for L in loss_fns:
        total_loss += L
        
    return total_loss
# vae.compile(loss=vae_loss,optimizer='rmsprop')

tandem_vae.compile(loss=vae_loss,optimizer='nadam',metrics=[recon_loss,recon_mse,xcov,acc,xentropy])

# %%
tandem_vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3136)         0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3000)         9411000     input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1500)         4501500     dense_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            3002        dense_2[0][0]
# __________________________________________________________________________________________________
# y_hat (Dense)                   (None, 10)           15010       dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           z_mean[0][0]
#                                                                  y_hat[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1500)         19500       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3000)         4503000     dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3136)         9411136     dense_4[0][0]
# ==================================================================================================
# Total params: 27,864,148
# Trainable params: 27,864,148
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
# logger = RemoteMonitor(root='http://localhost:9200',path='/tensorflow/train_batch/')
examples=10
choices = np.random.choice(np.arange(len(y_test)),examples)
test_ims = sx_train[choices[:3]]
# print(test_ims.shape)

es_logger = ElasticSearchMonitor(root='http://localhost:9200',path='/tensorflow')
ToN = TerminateOnNaN()

# %%
y_train_oh.shape
# Out:
# (60000, 10)

# %%
tandem_vae.fit(x=sx_train,y=y_train_oh,validation_split=0.1,
               shuffle=True,
               epochs=50,
               batch_size=128,
               callbacks=[es_logger,ToN],
               verbose=0
              )
# Out:
# session ID:  v0XCeD
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.020734655140726654', 'loss': '952.4202661494502', 'val_recon': '0.01702904339134693', 'val_xentropy': '1.0522211418151854', '@timestamp': '2018-08-31 13:15:12', 'val_loss': '449.8623502604167', 'recon_mse': '65.02388010547779', 'val_xcov': '0.006715804190685352', 'xcov': '0.0037697480585244126', 'val_recon_mse': '53.40308122762044', 'acc': '0.7554444444091232', 'xentropy': '2.226406504595721', 'val_acc': '0.8871666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.0171272240286624', 'loss': '340.0359240541811', 'val_recon': '0.016505607277154923', 'val_xentropy': '0.8299235138893127', '@timestamp': '2018-08-31 13:15:23', 'val_loss': '355.341033203125', 'recon_mse': '53.71097588546188', 'val_xcov': '0.008291919648647308', 'xcov': '0.008289296400767785', 'val_recon_mse': '51.761585042317705', 'acc': '0.9157037036507218', 'xentropy': '0.7917618234599079', 'val_acc': '0.9138333328564961'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01678576173964474', 'loss': '208.53763032588253', 'val_recon': '0.016056941390037535', 'val_xentropy': '0.8359259022076925', '@timestamp': '2018-08-31 13:15:35', 'val_loss': '357.93617757161456', 'recon_mse': '52.640149898952906', 'val_xcov': '0.009485238735874493', 'xcov': '0.010235154587499521', 'val_recon_mse': '50.354569112141924', 'acc': '0.9467037036860431', 'xentropy': '0.48365164627852264', 'val_acc': '0.9184999998410542'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01670317676663399', 'loss': '155.53880592176648', 'val_recon': '0.0161817464530468', 'val_xentropy': '0.8747015711466471', '@timestamp': '2018-08-31 13:15:46', 'val_loss': '374.35486824544273', 'recon_mse': '52.38116352561668', 'val_xcov': '0.00838093663752079', 'xcov': '0.010706747994102813', 'val_recon_mse': '50.745958221435544', 'acc': '0.960092592574932', 'xentropy': '0.3593906975587209', 'val_acc': '0.9231666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01659457793114362', 'loss': '124.82659356463397', 'val_recon': '0.0173975217739741', 'val_xentropy': '0.8911363412539164', '@timestamp': '2018-08-31 13:15:57', 'val_loss': '381.57918977864585', 'recon_mse': '52.04059756921839', 'val_xcov': '0.00819080013036728', 'xcov': '0.011012086608619602', 'val_recon_mse': '54.55862866210938', 'acc': '0.9687037036683824', 'xentropy': '0.2874210121543319', 'val_acc': '0.9211666661898296'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01660224011098897', 'loss': '106.23193408429181', 'val_recon': '0.016330841665466625', 'val_xentropy': '1.032806804339091', '@timestamp': '2018-08-31 13:16:08', 'val_loss': '441.8159732259115', 'recon_mse': '52.06462615740741', 'val_xcov': '0.00929233106970787', 'xcov': '0.011040176760819222', 'val_recon_mse': '51.213520243326826', 'acc': '0.9735925925572714', 'xentropy': '0.2438283996493728', 'val_acc': '0.9211666661898296'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01641868697051649', 'loss': '101.05888140982168', 'val_recon': '0.016390408287445705', 'val_xentropy': '0.877380494594574', '@timestamp': '2018-08-31 13:16:20', 'val_loss': '375.63200472005207', 'recon_mse': '51.489003261990014', 'val_xcov': '0.008510628653069337', 'xcov': '0.010130701453045562', 'val_recon_mse': '51.400320973714194', 'acc': '0.9754074073897467', 'xentropy': '0.23182217899958293', 'val_acc': '0.9275'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016456564181380803', 'loss': '90.53507074765805', 'val_recon': '0.015878380154569945', 'val_xentropy': '1.1355977284113565', '@timestamp': '2018-08-31 13:16:31', 'val_loss': '484.9969034830729', 'recon_mse': '51.60778647641782', 'val_xcov': '0.007764585400621096', 'xcov': '0.01037048243979613', 'val_recon_mse': '49.79460112508138', 'acc': '0.978407407425068', 'xentropy': '0.2071060531536738', 'val_acc': '0.9155000001589457'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01641951088000227', 'loss': '80.85813176020869', 'val_recon': '0.016355885341763497', 'val_xentropy': '1.088624836285909', '@timestamp': '2018-08-31 13:16:42', 'val_loss': '465.5712685546875', 'recon_mse': '51.491586875632954', 'val_xcov': '0.008551438247164091', 'xcov': '0.009819254627382314', 'val_recon_mse': '51.29205717976888', 'acc': '0.9806111110934504', 'xentropy': '0.18448717529906167', 'val_acc': '0.9213333328564962'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01635281795097722', 'loss': '80.01069252353244', 'val_recon': '0.016377001598477364', 'val_xentropy': '1.2479314908981323', '@timestamp': '2018-08-31 13:16:54', 'val_loss': '533.329569905599', 'recon_mse': '51.28243801540798', 'val_xcov': '0.009357222984234493', 'xcov': '0.009653153568644214', 'val_recon_mse': '51.358278045654295', 'acc': '0.9824814814814815', 'xentropy': '0.182414094792472', 'val_acc': '0.9163333330154418'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016404758351268593', 'loss': '79.49727981454355', 'val_recon': '0.01632251803576946', 'val_xentropy': '1.1119610249201457', '@timestamp': '2018-08-31 13:17:05', 'val_loss': '475.60730737304686', 'recon_mse': '51.44532319019459', 'val_xcov': '0.00752646957586209', 'xcov': '0.009169202894800239', 'val_recon_mse': '51.187417673746744', 'acc': '0.9822777777954385', 'xentropy': '0.18125897772665378', 'val_acc': '0.9246666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01639328451068313', 'loss': '62.4360895046658', 'val_recon': '0.016172404075662294', 'val_xentropy': '1.1479636619885762', '@timestamp': '2018-08-31 13:17:16', 'val_loss': '491.0854402669271', 'recon_mse': '51.4093413289388', 'val_xcov': '0.0085266276349624', 'xcov': '0.009189660467207431', 'val_recon_mse': '50.716660502115886', 'acc': '0.9865185184655366', 'xentropy': '0.14123717531837798', 'val_acc': '0.9284999998410542'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016394664115927837', 'loss': '83.65238605640553', 'val_recon': '0.016217592845360437', 'val_xentropy': '1.1588053766886393', '@timestamp': '2018-08-31 13:17:28', 'val_loss': '495.249919921875', 'recon_mse': '51.413667868155024', 'val_xcov': '0.007663475432743629', 'xcov': '0.009198323375510948', 'val_recon_mse': '50.85837249755859', 'acc': '0.9824629629806236', 'xentropy': '0.19097812298823286', 'val_acc': '0.9278333333333333'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016402080024834034', 'loss': '71.77678656966597', 'val_recon': '0.016217533009747664', 'val_xentropy': '1.1465365707377593', '@timestamp': '2018-08-31 13:17:39', 'val_loss': '490.06279626464845', 'recon_mse': '51.436923999927664', 'val_xcov': '0.007969732441008091', 'xcov': '0.00895039722930502', 'val_recon_mse': '50.85818466186524', 'acc': '0.9853148148501361', 'xentropy': '0.16317371287983326', 'val_acc': '0.9309999995231628'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016442548999631847', 'loss': '60.44731147879141', 'val_recon': '0.016107492859164872', 'val_xentropy': '1.147271090189616', '@timestamp': '2018-08-31 13:17:50', 'val_loss': '490.79960514322914', 'recon_mse': '51.56383458116319', 'val_xcov': '0.00839598839233319', 'xcov': '0.008966365424847161', 'val_recon_mse': '50.51309882609049', 'acc': '0.9877592592769199', 'xentropy': '0.1366725456248279', 'val_acc': '0.9303333338101705'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016442371577576356', 'loss': '60.96163019024884', 'val_recon': '0.01639539623260498', 'val_xentropy': '1.2073636600176494', '@timestamp': '2018-08-31 13:18:01', 'val_loss': '516.1398113606771', 'recon_mse': '51.563278042263455', 'val_xcov': '0.008996387685338655', 'xcov': '0.008736645600310079', 'val_recon_mse': '51.41596381632487', 'acc': '0.9871851851498639', 'xentropy': '0.1377764094118719', 'val_acc': '0.9281666666666667'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016506395151769673', 'loss': '62.628946499294706', 'val_recon': '0.016505700836579006', 'val_xentropy': '1.2372637793223062', '@timestamp': '2018-08-31 13:18:13', 'val_loss': '528.880273844401', 'recon_mse': '51.76405642248083', 'val_xcov': '0.0078104105691115065', 'xcov': '0.008830485716186188', 'val_recon_mse': '51.76187882486979', 'acc': '0.9879814814284996', 'xentropy': '0.14167991052533466', 'val_acc': '0.928833333492279'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016576438344187205', 'loss': '52.62216556633843', 'val_recon': '0.016619441792368888', 'val_xentropy': '1.2813215847810109', '@timestamp': '2018-08-31 13:18:24', 'val_loss': '547.5826575927734', 'recon_mse': '51.98371196831597', 'val_xcov': '0.008228507903714974', 'xcov': '0.008969737114453757', 'val_recon_mse': '52.1185710550944', 'acc': '0.9886851852028459', 'xentropy': '0.11819679993170279', 'val_acc': '0.931'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016593764385691396', 'loss': '65.76314505626537', 'val_recon': '0.01641516152024269', 'val_xentropy': '1.2135814293225606', '@timestamp': '2018-08-31 13:18:35', 'val_loss': '518.69403515625', 'recon_mse': '52.03804631551107', 'val_xcov': '0.007513256701330344', 'xcov': '0.008989877605051906', 'val_recon_mse': '51.47794770304362', 'acc': '0.9878333332803514', 'xentropy': '0.14901324050866618', 'val_acc': '0.9305000004768371'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01663523329684028', 'loss': '66.67869618564181', 'val_recon': '0.016466921562949818', 'val_xentropy': '1.3196491934458414', '@timestamp': '2018-08-31 13:18:47', 'val_loss': '564.161350423177', 'recon_mse': '52.168092703360095', 'val_xcov': '0.008080203704535962', 'xcov': '0.009019414765967263', 'val_recon_mse': '51.64026705932617', 'acc': '0.9874999999470181', 'xentropy': '0.15109085483386836', 'val_acc': '0.929833333492279'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01667402311883591', 'loss': '65.00244946006492', 'val_recon': '0.01663292002181212', 'val_xentropy': '1.478587198893229', '@timestamp': '2018-08-31 13:18:58', 'val_loss': '631.8144974772135', 'recon_mse': '52.289737445972584', 'val_xcov': '0.00836611869186163', 'xcov': '0.009521159205723691', 'val_recon_mse': '52.16083783976237', 'acc': '0.9876851851322033', 'xentropy': '0.147160263284213', 'val_acc': '0.9298333331743877'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01675286039268529', 'loss': '70.09410068992332', 'val_recon': '0.016747190202275913', 'val_xentropy': '1.329870671927929', '@timestamp': '2018-08-31 13:19:09', 'val_loss': '568.4463373514811', 'recon_mse': '52.536971297652634', 'val_xcov': '0.008530709604422251', 'xcov': '0.009195803095621092', 'val_recon_mse': '52.51918946329753', 'acc': '0.987574074074074', 'xentropy': '0.159047586850684', 'val_acc': '0.9281666666666667'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01676344328732402', 'loss': '54.168643214473015', 'val_recon': '0.016560995534062387', 'val_xentropy': '1.3559160924851894', '@timestamp': '2018-08-31 13:19:20', 'val_loss': '578.8670953674316', 'recon_mse': '52.57015933227539', 'val_xcov': '0.00726938225577275', 'xcov': '0.009351642755998505', 'val_recon_mse': '51.935282806396486', 'acc': '0.9906111111111111', 'xentropy': '0.12171782842402656', 'val_acc': '0.9320000001589457'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016728545189455702', 'loss': '51.99383865639015', 'val_recon': '0.01669850680232048', 'val_xentropy': '1.3709830646514893', '@timestamp': '2018-08-31 13:19:32', 'val_loss': '585.68784375', 'recon_mse': '52.460718775996455', 'val_xcov': '0.0073575253287951154', 'xcov': '0.00946832963851867', 'val_recon_mse': '52.36651823933919', 'acc': '0.9912962963139569', 'xentropy': '0.11670843457827275', 'val_acc': '0.9300000004768372'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016817407434185347', 'loss': '59.981890921133534', 'val_recon': '0.01708484308918317', 'val_xentropy': '1.4213911657333373', '@timestamp': '2018-08-31 13:19:43', 'val_loss': '607.1372576497396', 'recon_mse': '52.73939086009838', 'val_xcov': '0.008082944040497144', 'xcov': '0.009173539241292963', 'val_recon_mse': '53.57806919352213', 'acc': '0.9901851851322033', 'xentropy': '0.13538905652633143', 'val_acc': '0.926833333492279'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016867810370193588', 'loss': '58.85340221659342', 'val_recon': '0.01679757668574651', 'val_xentropy': '1.5121630271275839', '@timestamp': '2018-08-31 13:19:54', 'val_loss': '646.1186205240886', 'recon_mse': '52.89745450959382', 'val_xcov': '0.007561282227436701', 'xcov': '0.009730710155985974', 'val_recon_mse': '52.67720095825195', 'acc': '0.9901296296472902', 'xentropy': '0.13266761632253313', 'val_acc': '0.9268333338101705'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016891017192491777', 'loss': '58.905127755059134', 'val_recon': '0.016820572728912037', 'val_xentropy': '1.5331268692016602', '@timestamp': '2018-08-31 13:20:06', 'val_loss': '655.2958497721354', 'recon_mse': '52.970230962682656', 'val_xcov': '0.00866119791318973', 'xcov': '0.010023675990601381', 'val_recon_mse': '52.74931674194336', 'acc': '0.9901296296472902', 'xentropy': '0.1327942810072391', 'val_acc': '0.9290000003178914'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016942234401901565', 'loss': '62.732275050834374', 'val_recon': '0.016858725920319558', 'val_xentropy': '1.516197447538376', '@timestamp': '2018-08-31 13:20:17', 'val_loss': '647.9215423583985', 'recon_mse': '53.13084837849935', 'val_xcov': '0.010515440769493579', 'xcov': '0.010211027674790886', 'val_recon_mse': '52.86896508789062', 'acc': '0.9897962962962963', 'xentropy': '0.14170904926633188', 'val_acc': '0.9280000004768372'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016936018969173783', 'loss': '63.262898953473126', 'val_recon': '0.016745821525653203', 'val_xentropy': '1.5594694825808206', '@timestamp': '2018-08-31 13:20:28', 'val_loss': '666.342439453125', 'recon_mse': '53.11135657529478', 'val_xcov': '0.00793089234083891', 'xcov': '0.010167031594310646', 'val_recon_mse': '52.5148971862793', 'acc': '0.9895370370546976', 'xentropy': '0.14300628351727154', 'val_acc': '0.9305'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.0169633208502222', 'loss': '52.404104674727826', 'val_recon': '0.01706008512775103', 'val_xentropy': '1.5128974933624268', '@timestamp': '2018-08-31 13:20:40', 'val_loss': '647.0339777018229', 'recon_mse': '53.196975073920356', 'val_xcov': '0.008852473365763823', 'xcov': '0.010036930641090428', 'val_recon_mse': '53.50042825317383', 'acc': '0.9914259259259259', 'xentropy': '0.11750422733001997', 'val_acc': '0.9294999996821086'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017044887256291177', 'loss': '61.90683492985478', 'val_recon': '0.01705841830869516', 'val_xentropy': '1.6258196147282917', '@timestamp': '2018-08-31 13:20:51', 'val_loss': '694.7714434407552', 'recon_mse': '53.45276754760742', 'val_xcov': '0.0096545571560661', 'xcov': '0.010853369700411956', 'val_recon_mse': '53.49520120239258', 'acc': '0.9907777777424565', 'xentropy': '0.13980007111331927', 'val_acc': '0.924833333492279'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017026980163322554', 'loss': '55.3029560091937', 'val_recon': '0.016971971144278845', 'val_xentropy': '1.5518115526835123', '@timestamp': '2018-08-31 13:21:02', 'val_loss': '663.2089410807291', 'recon_mse': '53.39661083080151', 'val_xcov': '0.00823034943640232', 'xcov': '0.010487329431981952', 'val_recon_mse': '53.22410215250651', 'acc': '0.9914999999470181', 'xentropy': '0.12427279552314603', 'val_acc': '0.9326666665077209'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.016998262380008344', 'loss': '56.89146296126754', 'val_recon': '0.017070188174645107', 'val_xentropy': '1.7539065562884013', '@timestamp': '2018-08-31 13:21:13', 'val_loss': '748.8908684895833', 'recon_mse': '53.30655193526657', 'val_xcov': '0.009140016270180544', 'xcov': '0.010464178004198604', 'val_recon_mse': '53.532111958821616', 'acc': '0.9916481481834695', 'xentropy': '0.12810449100531535', 'val_acc': '0.9226666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017022514643492522', 'loss': '50.96291421169705', 'val_recon': '0.01705856844286124', 'val_xentropy': '1.6488328132629395', '@timestamp': '2018-08-31 13:21:25', 'val_loss': '704.3927472330729', 'recon_mse': '53.382606771963616', 'val_xcov': '0.009811746185024579', 'xcov': '0.010343355647943638', 'val_recon_mse': '53.4956716410319', 'acc': '0.9919259259435865', 'xentropy': '0.11412128558669118', 'val_acc': '0.9298333328564962'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.0170414649049441', 'loss': '52.131486707899306', 'val_recon': '0.017177561099330583', 'val_xentropy': '1.8215791889826456', '@timestamp': '2018-08-31 13:21:36', 'val_loss': '777.4851593424479', 'recon_mse': '53.4420348578559', 'val_xcov': '0.00998077404499054', 'xcov': '0.011325555297235649', 'val_recon_mse': '53.868832387288414', 'acc': '0.9916666666136847', 'xentropy': '0.11682137753488281', 'val_acc': '0.9266666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017070470791723993', 'loss': '68.94296598476834', 'val_recon': '0.016955887640515963', 'val_xentropy': '1.8706107603708904', '@timestamp': '2018-08-31 13:21:47', 'val_loss': '798.62440625', 'recon_mse': '53.53299757441768', 'val_xcov': '0.010381482936441899', 'xcov': '0.011456799277552852', 'val_recon_mse': '53.17366559855143', 'acc': '0.9905740740210922', 'xentropy': '0.15621027865424683', 'val_acc': '0.9280000004768372'}
# /home/elijahc/.pyenv/versions/jupyterlab-gpu/lib/python3.5/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.112583). Check your callbacks.
#   % delta_t_median)
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01718702645710221', 'loss': '83.67331095151548', 'val_recon': '0.017218284224470456', 'val_xentropy': '1.7284973055521646', '@timestamp': '2018-08-31 13:21:59', 'val_loss': '737.4496994628906', 'recon_mse': '53.898516173186124', 'val_xcov': '0.009516667144993942', 'xcov': '0.011805244006906395', 'val_recon_mse': '53.996540334065756', 'acc': '0.9884259259435866', 'xentropy': '0.19077244547107775', 'val_acc': '0.9284999995231629'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017219316068070905', 'loss': '50.27870056653906', 'val_recon': '0.01730278923610846', 'val_xentropy': '1.692930773417155', '@timestamp': '2018-08-31 13:22:10', 'val_loss': '721.9386408691406', 'recon_mse': '53.999776346842445', 'val_xcov': '0.009014308092494806', 'xcov': '0.011067868572694284', 'val_recon_mse': '54.261548116048175', 'acc': '0.9922962962962963', 'xentropy': '0.11241742935160572', 'val_acc': '0.932'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017157669929442582', 'loss': '43.91498151595504', 'val_recon': '0.017240829065442085', 'val_xentropy': '1.5673281450271606', '@timestamp': '2018-08-31 13:22:21', 'val_loss': '669.247681640625', 'recon_mse': '53.806454153555414', 'val_xcov': '0.00944386565933625', 'xcov': '0.011548700890331356', 'val_recon_mse': '54.06724175008138', 'acc': '0.9937222221692403', 'xentropy': '0.09753663621995602', 'val_acc': '0.936833333492279'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017187222900765912', 'loss': '61.324131436100714', 'val_recon': '0.01720369228720665', 'val_xentropy': '1.9595812536875408', '@timestamp': '2018-08-31 13:22:32', 'val_loss': '836.8174855143229', 'recon_mse': '53.899132250750505', 'val_xcov': '0.012364860860009989', 'xcov': '0.011440803738931814', 'val_recon_mse': '53.950779947916665', 'acc': '0.991999999947018', 'xentropy': '0.1383115895823748', 'val_acc': '0.9268333328564962'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017232379970175248', 'loss': '51.66604949894658', 'val_recon': '0.017231951599319777', 'val_xentropy': '1.848285808722178', '@timestamp': '2018-08-31 13:22:43', 'val_loss': '789.7155903320313', 'recon_mse': '54.04074481201172', 'val_xcov': '0.01133891242245833', 'xcov': '0.012522896009876772', 'val_recon_mse': '54.03940170288086', 'acc': '0.9931296295766477', 'xentropy': '0.11564246267228628', 'val_acc': '0.9296666661898295'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017229829089509117', 'loss': '50.50967132172761', 'val_recon': '0.017149359419941904', 'val_xentropy': '1.681479521592458', '@timestamp': '2018-08-31 13:22:55', 'val_loss': '718.8347979329427', 'recon_mse': '54.03274519743743', 'val_xcov': '0.010179493330419063', 'xcov': '0.011573024344113138', 'val_recon_mse': '53.78039210001628', 'acc': '0.9932037037037037', 'xentropy': '0.11294412086672674', 'val_acc': '0.9331666669845581'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01718306269634653', 'loss': '59.80089763839157', 'val_recon': '0.017453919877608616', 'val_xentropy': '2.2966979995965957', '@timestamp': '2018-08-31 13:23:06', 'val_loss': '980.5015808919271', 'recon_mse': '53.88608576230649', 'val_xcov': '0.014834000937640666', 'xcov': '0.012198529982456454', 'val_recon_mse': '54.735494232177736', 'acc': '0.9932037036507217', 'xentropy': '0.1347891272597575', 'val_acc': '0.9255000004768371'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017406577908330494', 'loss': '86.85299051298918', 'val_recon': '0.01726418534417947', 'val_xentropy': '2.030773816426595', '@timestamp': '2018-08-31 13:23:18', 'val_loss': '866.8278583984375', 'recon_mse': '54.587029425726996', 'val_xcov': '0.01211259159942468', 'xcov': '0.012819716471764777', 'val_recon_mse': '54.14048659261068', 'acc': '0.9894814814814815', 'xentropy': '0.1980436508321017', 'val_acc': '0.9256666666666666'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01735175771790522', 'loss': '69.80081490467212', 'val_recon': '0.01720727730790774', 'val_xentropy': '1.8839834874471029', '@timestamp': '2018-08-31 13:23:29', 'val_loss': '805.5562194824219', 'recon_mse': '54.41511308571145', 'val_xcov': '0.011026645861566067', 'xcov': '0.012516600540390721', 'val_recon_mse': '53.96202261352539', 'acc': '0.991870370388031', 'xentropy': '0.15821915497427216', 'val_acc': '0.9293333330154419'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017361514627381607', 'loss': '60.25816827392578', 'val_recon': '0.017585581799348195', 'val_xentropy': '1.867760006268819', '@timestamp': '2018-08-31 13:23:40', 'val_loss': '798.0911375325521', 'recon_mse': '54.44571107991536', 'val_xcov': '0.011768308294316132', 'xcov': '0.012438405193112515', 'val_recon_mse': '55.148385762532556', 'acc': '0.9926296295766477', 'xentropy': '0.13575524681556486', 'val_acc': '0.9298333338101705'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017331895063872692', 'loss': '53.21966894757306', 'val_recon': '0.01749406911432743', 'val_xentropy': '1.9830535278320311', '@timestamp': '2018-08-31 13:23:52', 'val_loss': '847.2487410481771', 'recon_mse': '54.35282396556713', 'val_xcov': '0.01151259599501888', 'xcov': '0.012990494248491746', 'val_recon_mse': '54.86140171305338', 'acc': '0.9931666666136848', 'xentropy': '0.11924944994334645', 'val_acc': '0.9288333331743877'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017298843236433135', 'loss': '54.45188371502912', 'val_recon': '0.017305807381868363', 'val_xentropy': '1.8320387665430704', '@timestamp': '2018-08-31 13:24:03', 'val_loss': '782.3934149576822', 'recon_mse': '54.24917350373445', 'val_xcov': '0.01326295304298401', 'xcov': '0.012726031591494878', 'val_recon_mse': '54.271013295491535', 'acc': '0.9937592592062774', 'xentropy': '0.12224440547456523', 'val_acc': '0.9328333333333333'}
# /home/elijahc/.pyenv/versions/jupyterlab-gpu/lib/python3.5/site-packages/keras/callbacks.py:120: UserWarning: Method on_batch_end() is slow compared to the batch update (0.128013). Check your callbacks.
#   % delta_t_median)
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.01726394281619125', 'loss': '50.74940968704224', 'val_recon': '0.017272747750083604', 'val_xentropy': '1.8577062071412802', '@timestamp': '2018-08-31 13:24:14', 'val_loss': '793.5992333831787', 'recon_mse': '54.139725756609884', 'val_xcov': '0.011344197998444239', 'xcov': '0.013082434821459982', 'val_recon_mse': '54.16733806355794', 'acc': '0.9938703703703704', 'xentropy': '0.11345949493961571', 'val_acc': '0.9326666671435039'}
# posted epoch results!
# {'session': 'v0XCeD', 'recon': '0.017242875155475405', 'loss': '63.96502417613842', 'val_recon': '0.01721886693437894', 'val_xentropy': '1.960928530772527', '@timestamp': '2018-08-31 13:24:25', 'val_loss': '837.3514267578125', 'recon_mse': '54.073657803005645', 'val_xcov': '0.012488598167896272', 'xcov': '0.012777414321347519', 'val_recon_mse': '53.998367614746094', 'acc': '0.9927592592062774', 'xentropy': '0.14448816645732587', 'val_acc': '0.9316666661898295'}

# %%
tandem_vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3136)         0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3000)         9411000     input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1500)         4501500     dense_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            3002        dense_2[0][0]
# __________________________________________________________________________________________________
# y_hat (Dense)                   (None, 10)           15010       dense_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12)           0           z_mean[0][0]
#                                                                  y_hat[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1500)         19500       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3000)         4503000     dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3136)         9411136     dense_4[0][0]
# ==================================================================================================
# Total params: 27,864,148
# Trainable params: 27,864,148
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
z_mean_encoder = Model(inputs,z_mean)
y_hat_encoder = Model(inputs,y_hat)
# y_int_encoder = Model(inputs,y_int)
classifier = Model(inputs,y_class)
decoder_inp = Input(shape=(10+z_dim,))
dec_layers = tandem_vae.layers[-3:]
_gen_x = dec_layers[0](decoder_inp)
_gen_x = dec_layers[1](_gen_x)
_gen_x = dec_layers[2](_gen_x)
generator = Model(decoder_inp,_gen_x)

# %%
classifier.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3000)              9411000
# _________________________________________________________________
# dense_2 (Dense)              (None, 1500)              4501500
# _________________________________________________________________
# y_hat (Dense)                (None, 10)                15010
# =================================================================
# Total params: 13,927,510
# Trainable params: 13,927,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
z_mean_enc = z_mean_encoder.predict(sx_test,batch_size=128)
y_class_enc = classifier.predict(sx_test,batch_size=128)
y_hat_enc = y_hat_encoder.predict(sx_test,batch_size=128)
# y_int_enc = y_int_encoder.predict(sx_test,batch_size=128)

# %%
y_test
plt.scatter(y_hat_enc[:,1],y_hat_enc[:,2],c=y_test,cmap='magma')
plt.xlabel('y_0')
plt.ylabel('y_1')
plt.title(r"Latent Dimension $\hat{Y}$")
plt.colorbar()

# %%
# tandem_vae.save_weights('../models/tandem_vae/vae_weights.h5')
# generator.save_weights('../models/tandem_vae/generator_weights.h5')
# lat_encoder.save_weights('../models/tandem_vae/encoder.h5')

# %%
classifier.compile(loss='categorical_crossentropy',optimizer='adagrad',metrics=['accuracy'])
classifier_perf = classifier.evaluate(sx_test,to_categorical(y_test,num_classes=10))

print('Classification Accuracy: ',classifier_perf[1])
# Out:
# 10000/10000 [==============================] - 1s 55us/step
# Classification Accuracy:  0.9228

# %%
fig,axs = plt.subplots(1,2)

axs[0].hist2d(z_mean_enc[:,0],z_mean_enc[:,1]);
axs[1].hist2d(delta_test[:,0],delta_test[:,1]);
# plt.colorbar()

# %%
examples=5
sns.set_context('talk')
# sns.set_style('whitegrid')
y_test_oh = to_categorical(y_test,num_classes=10)

z0mean = z_mean_enc[:,0].mean()
z1mean = z_mean_enc[:,1].mean()
z0_sigma = z_mean_enc[:,0].std()
z1_sigma = z_mean_enc[:,1].std()
# z2_sigma = x_test_lat_enc[:,2].std()

fig,axs = plt.subplots(examples,4,figsize=(6,8))
choices = np.random.choice(np.arange(len(y_test)),examples)
# lat_vec_ = z_mean_enc[choices]
lat_vec_ = np.concatenate([z_mean_enc[choices],y_hat_enc[choices]],axis=1)
print(lat_vec_.shape)
dec_test = generator.predict(lat_vec_)

# print(x_test_encoded[choices])

for i,idx in enumerate(choices):
    rec_true_im = x_test[idx].reshape(28,28)
    in_im = sx_test[idx].reshape(28*2,28*2)
    dec_im = dec_test[i].reshape(28*2,28*2)
    
    axs[i,0].imshow(rec_true_im)
    axs[i,0].set_xticklabels([])
    axs[i,0].set_yticklabels([])
    
    axs[i,1].imshow(in_im)
    axs[i,1].set_xticklabels([])
    axs[i,1].set_yticklabels([])
    
    axs[i,2].imshow(dec_im)
    axs[i,2].set_xticklabels([])
    axs[i,2].set_yticklabels([])
#     axs[2,i].set_xlabel("class: {}".format(str(np.argmax(y_class_enc[idx]))))
    
    axs[i,3].imshow(y_class_enc[idx].reshape(-1,1).T)
    axs[i,3].set_xticklabels([])
    axs[i,3].set_yticklabels([])
    axs[i,3].set_xlabel("class: {}".format(str(np.argmax(y_class_enc[idx]))))
    
# plt.tight_layout()
# sns.despine(fig=fig)
# plt.imshow(dec_test[2].reshape(28,28).T)
# Out:
# (5, 12)

# %%
idx=2
bins = 11

all_sweeps = np.empty((examples,bins,4*784))


z0s = np.linspace(z0mean+(-2*z0_sigma),z0mean+(2*z0_sigma),num=bins)
z1s = np.linspace(z1mean+(-2*z1_sigma),z1mean+(2*z0_sigma),num=bins)
# z2s = np.linspace(-2*z2_sigma,2*z2_sigma,num=10)

fig,axs = plt.subplots(examples,bins,figsize=(15,int(15*(examples/bins))))

for j,vec in enumerate(lat_vec_):
    lat_size = vec.shape[-1]
    sweep = np.empty((bins,lat_size))
    
    for i,z in enumerate(z0s):
        sweep[i] = vec
        sweep[i,0] = z
    
    im_sweep = generator.predict(sweep)
    all_sweeps[j]=im_sweep
    
for i in np.arange(examples):
    for j in np.arange(bins):
        axs[i,j].imshow(all_sweeps[i,j].reshape(56,56))
        axs[i,j].set_xticklabels([])
        axs[i,j].set_yticklabels([])
        
plt.tight_layout()

# %%
fig,axs = plt.subplots(examples,bins,figsize=(14,int(14*(examples/bins))))

for j,vec in enumerate(lat_vec_):
    lat_size = vec.shape[-1]
    sweep = np.empty((bins,lat_size))
    for i,z in enumerate(z1s):
        sweep[i] = vec
        sweep[i,1] = z
    
    im_sweep = generator.predict(sweep)
    all_sweeps[j]=im_sweep
    
for i in np.arange(examples):
    for j in np.arange(bins):
        axs[i,j].imshow(all_sweeps[i,j].reshape(56,56))
        axs[i,j].set_xticklabels([])
        axs[i,j].set_yticklabels([])
plt.tight_layout()

# %%
sns.set_context('notebook')
dxs = delta_test[:,0]
dys = delta_test[:,1]

g = sns.jointplot(dxs-14,z_mean_enc[:,0])
g.set_axis_labels(xlabel='dx',ylabel='lat_z0')
# Out:
# /home/elijahc/.pyenv/versions/jupyterlab-gpu/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(dys-14,z_mean_enc[:,1])
# Out:
# /home/elijahc/.pyenv/versions/jupyterlab-gpu/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.scatter(z_mean_enc[:,0],z_mean_enc[:,1],c=dxs-14)
plt.colorbar()
plt.title(r"dx in $\hat{Z}$")
plt.xlabel(r"$\hat{Z_0}$")
plt.ylabel(r"$\hat{Z_1}$")
# Out:
# Text(0,0.5,'$\\hat{Z_1}$')

# %%
plt.scatter(z_mean_enc[:,0],z_mean_enc[:,1],c=dys-14)
plt.colorbar()
plt.title(r"dy in $\hat{Z}$")
plt.xlabel(r"$\hat{Z_0}$")
plt.ylabel(r"$\hat{Z_1}$")
# Out:
# Text(0,0.5,'$\\hat{Z_1}$')

# %%
# fig,axs = plt.subplots(1,2,figsize=(12,5))
plt.scatter(dxs-14,dys-14,c=z_mean_enc[:,0])
# con = plt.contourf(dxs-14,dys-14,z_mean_enc[:,0])
# ax[1].scatter(dxs-14,dys-14,c=z_mean_enc[:,1])
# ax[0].set_xlabel('dx')
# ax[1].set_ylabel('dy')
plt.colorbar()
# plt.title('Latent Variable by x-shift (dx)')

# %%
# fig,ax = plt.subplots(1,1,figsize=(5,5))
plt.scatter(dxs-14,dys-14,c=z_mean_enc[:,1],)
plt.xlabel('z_0')
plt.ylabel('z_1')
plt.title('Latent Variable by y-shift (dy)')

plt.colorbar()

# %%
# from sklearn.manifold import Isomap

# iso = Isomap(n_neighbors=20,n_components=1)
# lat_enc_iso = iso.fit_transform(X=x_test_lat_enc)

# %%
# lat_enc_iso.shape

# %%
plt.scatter(np.squeeze(lat_enc_iso),dxs-14,c=y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-91d43f24a15c> in <module>()
# ----> 1 plt.scatter(np.squeeze(lat_enc_iso),dxs-14,c=y_test)
#
# NameError: name 'lat_enc_iso' is not defined

# %%
plt.scatter(np.squeeze(lat_enc_iso),dys-14,c=y_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
plt.scatter(x_test_loc_enc[:, 0], x_test_loc_enc[:, 1],
            c=y_test,alpha=0.5
           )
plt.colorbar()
plt.scatter(x=x_test_loc_enc[choices][:,0],y=x_test_loc_enc[choices][:,1],marker='+',
            s=20**2,color='k')
plt.show()

# %%
import bqplot.pyplot as bqplt
from bqplot import Tooltip
import pandas as pd

recs = []
for i,cid in enumerate(y_test):
    recs.append(dict(
        loc_z=x_test_loc_enc[i],
        loc_z0=x_test_loc_enc[i][0],
        loc_z1=x_test_loc_enc[i][1],
        id_z=x_test_encoded[i],
        id_z0=x_test_encoded[i][0],
        id_z1=x_test_encoded[i][1],
        class_id=cid,
        dx=delta_test[i][0],
        dy=delta_test[i][1]
    ))
enc_df = pd.DataFrame.from_records(recs)
enc_df.head()

# %%
enc_df.to_pickle('./tandem_encoder_df.pk')
np.save('./sx_test.npy',sx_test)
np.save('./dec_test.npy',dec_test)

# %%
# bqplt.figure(title='Autoencoder Latent Space')
# def_tt = Tooltip(fields=['x', 'y'], formats=['', '.2f'])
# bqplt.scatter(enc_df.loc_z0.values,enc_df.loc_z1.values)
# # plt.colorbar()
# bqplt.show()
